# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D,Activation,BatchNormalization
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
import numpy as np

#Load dataset
(train_X,train_Y),(test_X,test_Y) = tf.keras.datasets.cifar10.load_data()

#Parse numbers as floats
train_X=train_X.astype('float32')
test_X=test_X.astype('float32')

#Normalize data
train_X=train_X/255.0
test_X=test_X/255.0

#One-hot encoding for target classes
train_Y=to_categorical(train_Y)
test_Y=to_categorical(test_Y)

#Creating the model
model1=Sequential()
model1.add(Conv2D(32,(3,3),input_shape=(32,32,3),padding='same',activation='relu'))
model1.add(Dropout(0.2))
model1.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model1.add(MaxPooling2D((2,2)))
model1.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model1.add(Flatten())
model1.add(Dense(512,activation='relu'))
model1.add(Dropout(0.5))
model1.add(Dense(10, activation='softmax'))

model1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model1.summary()

model1.fit(train_X,train_Y,validation_data=(test_X,test_Y),epochs=10,batch_size=32)

model1.evaluate(test_X, test_Y)

model1.save("model1.h5")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/noxwiz/Desktop/2021-2022 ders/Yapay Zeka Yöntemleri/Proje 2/05180000029_05180000746/imageClassification.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/noxwiz/Desktop/2021-2022%20ders/Yapay%20Zeka%20Yo%CC%88ntemleri/Proje%202/05180000029_05180000746/imageClassification.ipynb#ch0000000?line=0'>1</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/Users/noxwiz/Desktop/2021-2022%20ders/Yapay%20Zeka%20Yo%CC%88ntemleri/Proje%202/05180000029_05180000746/imageClassification.ipynb#ch0000000?line=1'>2</a> from tensorflow import keras
#       <a href='vscode-notebook-cell:/Users/noxwiz/Desktop/2021-2022%20ders/Yapay%20Zeka%20Yo%CC%88ntemleri/Proje%202/05180000029_05180000746/imageClassification.ipynb#ch0000000?line=2'>3</a> from tensorflow.keras.models import Sequential
#
# ...

# %%
model2=Sequential()
model2.add(Conv2D(32,(3,3),input_shape=(32,32,3),padding='same',activation='relu'))
model2.add(MaxPooling2D((2,2)))
model2.add(Dropout(0.2))
model2.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model2.add(MaxPooling2D((2,2)))
model2.add(Dropout(0.2))
model2.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model2.add(Flatten())
model2.add(Dense(512,activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model2.summary()

model2.fit(train_X,train_Y,validation_data=(test_X,test_Y),epochs=20)

model2.evaluate(test_X, test_Y)

model2.save("model2.h5")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_12 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 64)          36928
# ...

# %%
model3=Sequential()
model3.add(Conv2D(32,(3,3),input_shape=(32,32,3),padding='same',activation='relu'))
model3.add(MaxPooling2D((2,2)))
model3.add(Dropout(0.2))
model3.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model3.add(MaxPooling2D((2,2)))
model3.add(Dropout(0.2))
model3.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model3.add(MaxPooling2D((2,2)))
model3.add(Dropout(0.2))
model3.add(Flatten())
model3.add(Dense(512,activation='relu',kernel_constraint=max_norm(3)))
model3.add(Dropout(0.5))
model3.add(Dense(10, activation='softmax'))

opt=SGD(learning_rate=0.01,momentum=0.9)
 
model3.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

model3.summary()

model3.fit(train_X,train_Y,validation_data=(test_X,test_Y),epochs=20)

model3.evaluate(test_X, test_Y)

model3.save("model3.h5")
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_24 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 8, 8, 128)         73856
# ...

# %%
initializer = tf.keras.initializers.HeUniform()
model4 = Sequential()
model4.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer, padding='same', input_shape=(32, 32, 3)))
model4.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
model4.add(MaxPooling2D((2, 2)))
model4.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
model4.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
model4.add(MaxPooling2D((2, 2)))
model4.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
model4.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
model4.add(MaxPooling2D((2, 2)))
model4.add(Flatten())
model4.add(Dense(128, activation='relu', kernel_initializer=initializer))
model4.add(Dense(10, activation='softmax'))

opt = SGD(learning_rate=0.01,momentum=0.9)
model4.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model4.summary()

model4.fit(train_X, train_Y, validation_split = 0.33, epochs=100, batch_size=64, shuffle=True)

model4.evaluate(test_X, test_Y)

model4.save("model4.h5")
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_33 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 8, 8, 128)         73856
# ...

# %%
from sklearn.model_selection import KFold

(train_X, train_Y), (test_X, test_Y) = tf.keras.datasets.cifar10.load_data()

# Parse numbers as floats
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')

# Normalize data
train_X = train_X / 255.0
test_X = test_X / 255.0

# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []

# Merge inputs and targets
inputs = np.concatenate((train_X, test_X), axis=0)
targets = np.concatenate((train_Y, test_Y), axis=0)

# Define the K-fold Cross Validator
num_folds = 10
kfold = KFold(n_splits=num_folds, shuffle=True)

# K-fold Cross Validation model evaluation
fold_no = 1
for train, test in kfold.split(inputs, targets):
    # Define the model architecture
    initializer = tf.keras.initializers.HeUniform()
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer, padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=initializer))
    model.add(Dense(10, activation='softmax'))

    # Compile the model
    opt = SGD(learning_rate=0.01,momentum=0.9,decay=(0.01/25),nesterov=False)
    model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')

    # Fit data to model
    history = model.fit(inputs[train], targets[train], batch_size=64, epochs=100, shuffle=True)

    # Generate generalization metrics
    scores = model.evaluate(inputs[test], targets[test])
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1] * 100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])

    model_name = "kFoldModel" + str(fold_no) + ".h5"
    print("Model Name: " + model_name)

    model.save(model_name)

    # Increase fold number
    fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i + 1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 844/844 [==============================] - 7s 8ms/step - loss: 1.5410 - accuracy: 0.4418
# Epoch 2/100
# 844/844 [==============================] - 7s 8ms/step - loss: 1.0264 - accuracy: 0.6373
# Epoch 3/100
# 844/844 [==============================] - 7s 8ms/step - loss: 0.8209 - accuracy: 0.7128
# Epoch 4/100
# 844/844 [==============================] - 7s 8ms/step - loss: 0.6844 - accuracy: 0.7615
# Epoch 5/100
# 844/844 [==============================] - 7s 8ms/step - loss: 0.5803 - accuracy: 0.7975
# Epoch 6/100
# 844/844 [==============================] - 7s 8ms/step - loss: 0.4789 - accuracy: 0.8336
# Epoch 7/100
# 844/844 [==============================] - 7s 8ms/step - loss: 0.3907 - accuracy: 0.8631
# Epoch 8/100
# 844/844 [==============================] - 7s 8ms/step - loss: 0.3144 - accuracy: 0.8907
# Epoch 9/100
# ...
